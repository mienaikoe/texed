# %% [markdown]
# # Cleaning Script
#
# This script is to explore TAPR data for 4-year longitudinal studies and make the CAMPCOMP data more useful for data studies. The output of this notebook is a csv that can be used in the `correlation-campcomp` notebook.

# %%
import pandas as pd

# %%
import re

# %%
year = 2020
filename = f'CAMPCOMP_{year}'

# %%
# Source
# https://rptsvr1.tea.texas.gov/perfreport/tapr/2021/download/DownloadData.html
df = pd.read_csv(f'./{filename}.csv', na_values=['.','-1','-3'])

# %%
df
# Out:
#           CAMPUS DISTRICT  CA2C4X20N  CB2C4X20N  CI2C4X20N  C32C4X20N  \
# 0     '001902001  '001902       39.0        NaN        NaN        NaN
# 1     '001902041  '001902        NaN        NaN        NaN        NaN
# 2     '001902103  '001902        NaN        NaN        NaN        NaN
# 3     '001903001  '001903       89.0        6.0        NaN        NaN
# 4     '001903041  '001903        NaN        NaN        NaN        NaN
# ...          ...      ...        ...        ...        ...        ...
# 8835  '254901101  '254901        NaN        NaN        NaN        NaN
# 8836  '254901104  '254901        NaN        NaN        NaN        NaN
# 8837  '254901106  '254901        NaN        NaN        NaN        NaN
# 8838  '254902001  '254902       41.0        NaN        NaN        NaN
# 8839  '254902101  '254902        NaN        NaN        NaN        NaN
#
#       CH2C4X20N  C42C4X20N  CW2C4X20N  C22C4X20N  ...  CHGC617R  C4GC617R  \
# 0           NaN        NaN       33.0        NaN  ...       NaN       NaN
# 1           NaN        NaN        NaN        NaN  ...       NaN       NaN
# 2           NaN        NaN        NaN        NaN  ...       NaN       NaN
# 3          10.0        NaN       67.0        NaN  ...     100.0       NaN
# 4           NaN        NaN        NaN        NaN  ...       NaN       NaN
# ...         ...        ...        ...        ...  ...       ...       ...
# 8835        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 8836        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 8837        NaN        NaN        NaN        NaN  ...       NaN       NaN
# 8838       41.0        NaN        NaN        NaN  ...      89.5       NaN
# 8839        NaN        NaN        NaN        NaN  ...       NaN       NaN
#
#       CWGC617R  C2GC617R  CEGC617R  CFGC617R  CMGC617R  CSGC617R  CRGC617R  \
# 0         97.6       NaN      93.3      95.2      96.3      91.7      93.8
# 1          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         97.2       NaN      97.5     100.0      95.7     100.0      98.2
# 4          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 8835       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8836       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8837       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8838       NaN       NaN      87.5      93.3      88.9       NaN      87.5
# 8839       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#       CLGC617R
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 8835       NaN
# 8836       NaN
# 8837       NaN
# 8838       NaN
# 8839       NaN
#
# [8840 rows x 1348 columns]

# %%
# Source: https://rptsvr1.tea.texas.gov/perfreport/tapr/2018/download/ccomp4.html
cols_df = pd.read_csv('./tea-cols-campus.csv', index_col='tea_id')
cols_df
# Out:
#                                                         name
# tea_id
# CAMPUS                                         Campus Number
# CB0C4X16D  Campus 2016 4-Year Longitudinal: African Ameri...
# CA0C4X16D  Campus 2016 4-Year Longitudinal: All Students ...
# CI0C4X16D  Campus 2016 4-Year Longitudinal: American Indi...
# C30C4X16D  Campus 2016 4-Year Longitudinal: Asian Denomin...
# ...                                                      ...
# CWGC420N   Campus 2020 4-Year Longitudinal: [Graduates] f...
# CWGC420R   Campus 2020 4-Year Longitudinal: [Graduates] f...
# CAMPNAME                                         Campus Name
# DISTNAME                                       District Name
# DISTRICT                                     District Number
#
# [900 rows x 1 columns]

# %%
cols_map = cols_df.to_dict('index')
cols_map = {key: re.sub(r'Campus (20\d\d) 4-Year Longitudinal: ', r'\1 ', value['name']) for (key, value) in cols_map.items()}
final_table_columns = cols_map.keys()

cols_map
# Out:
# {'CAMPUS': 'Campus Number',
#  'CB0C4X16D': '2016 African American Denominator',
#  'CA0C4X16D': '2016 All Students Denominator',
#  'CI0C4X16D': '2016 American Indian Denominator',
#  'C30C4X16D': '2016 Asian Denominator',
#  'CR0C4X16D': '2016 At Risk Denominator',
#  'CE0C4X16D': '2016 Econ Disadv Denominator',
#  'CF0C4X16D': '2016 Female Denominator',
#  'CH0C4X16D': '2016 Hispanic Denominator',
#  'CL0C4X16D': '2016 LEP Denominator',
#  'CM0C4X16D': '2016 Male Denominator',
#  'C40C4X16D': '2016 Pacific Islander Denominator',
#  'CS0C4X16D': '2016 Special Ed Denominator',
#  'C20C4X16D': '2016 Two or More Races Denominator',
#  'CW0C4X16D': '2016 White Denominator',
#  'CBNC4X16N': '2016 [Continuers] for African American Numerator',
#  'CBNC4X16R': '2016 [Continuers] for African American Rate',
#  'CANC4X16N': '2016 [Continuers] for All Students Numerator',
#  'CANC4X16R': '2016 [Continuers] for All Students Rate',
#  'CINC4X16N': '2016 [Continuers] for American Indian Numerator',
#  'CINC4X16R': '2016 [Continuers] for American Indian Rate',
#  'C3NC4X16N': '2016 [Continuers] for Asian Numerator',
#  'C3NC4X16R': '2016 [Continuers] for Asian Rate',
#  'CRNC4X16N': '2016 [Continuers] for At Risk Numerator',
#  'CRNC4X16R': '2016 [Continuers] for At Risk Rate',
#  'CENC4X16N': '2016 [Continuers] for Econ Disadv Numerator',
#  'CENC4X16R': '2016 [Continuers] for Econ Disadv Rate',
#  'CFNC4X16N': '2016 [Continuers] for Female Numerator',
#  'CFNC4X16R': '2016 [Continuers] for Female Rate',
#  'CHNC4X16N': '2016 [Continuers] for Hispanic Numerator',
#  'CHNC4X16R': '2016 [Continuers] for Hispanic Rate',
#  'CLNC4X16N': '2016 [Continuers] for LEP Numerator',
#  'CLNC4X16R': '2016 [Continuers] for LEP Rate',
#  'CMNC4X16N': '2016 [Continuers] for Male Numerator',
#  'CMNC4X16R': '2016 [Continuers] for Male Rate',
#  'C4NC4X16N': '2016 [Continuers] for Pacific Islander Numerator',
#  'C4NC4X16R': '2016 [Continuers] for Pacific Islander Rate',
#  'CSNC4X16N': '2016 [Continuers] for Special Ed Numerator',
#  'CSNC4X16R': '2016 [Continuers] for Special Ed Rate',
#  'C2NC4X16N': '2016 [Continuers] for Two or More Races Numerator',
#  'C2NC4X16R': '2016 [Continuers] for Two or More Races Rate',
#  'CWNC4X16N': '2016 [Continuers] for White Numerator',
#  'CWNC4X16R': '2016 [Continuers] for White Rate',
#  'CBDC4X16N': '2016 [Dropout] for African American Numerator',
#  'CBDC4X16R': '2016 [Dropout] for African American Rate',
#  'CADC4X16N': '2016 [Dropout] for All Students Numerator',
#  'CADC4X16R': '2016 [Dropout] for All Students Rate',
#  'CIDC4X16N': '2016 [Dropout] for American Indian Numerator',
#  'CIDC4X16R': '2016 [Dropout] for American Indian Rate',
#  'C3DC4X16N': '2016 [Dropout] for Asian Numerator',
#  'C3DC4X16R': '2016 [Dropout] for Asian Rate',
#  'CRDC4X16N': '2016 [Dropout] for At Risk Numerator',
#  'CRDC4X16R': '2016 [Dropout] for At Risk Rate',
#  'CEDC4X16N': '2016 [Dropout] for Econ Disadv Numerator',
#  'CEDC4X16R': '2016 [Dropout] for Econ Disadv Rate',
#  'CFDC4X16N': '2016 [Dropout] for Female Numerator',
#  'CFDC4X16R': '2016 [Dropout] for Female Rate',
#  'CHDC4X16N': '2016 [Dropout] for Hispanic Numerator',
#  'CHDC4X16R': '2016 [Dropout] for Hispanic Rate',
#  'CLDC4X16N': '2016 [Dropout] for LEP Numerator',
#  'CLDC4X16R': '2016 [Dropout] for LEP Rate',
#  'CMDC4X16N': '2016 [Dropout] for Male Numerator',
#  'CMDC4X16R': '2016 [Dropout] for Male Rate',
#  'C4DC4X16N': '2016 [Dropout] for Pacific Islander Numerator',
#  'C4DC4X16R': '2016 [Dropout] for Pacific Islander Rate',
#  'CSDC4X16N': '2016 [Dropout] for Special Ed Numerator',
#  'CSDC4X16R': '2016 [Dropout] for Special Ed Rate',
#  'C2DC4X16N': '2016 [Dropout] for Two or More Races Numerator',
#  'C2DC4X16R': '2016 [Dropout] for Two or More Races Rate',
#  'CWDC4X16N': '2016 [Dropout] for White Numerator',
#  'CWDC4X16R': '2016 [Dropout] for White Rate',
#  'CBEC4X16N': '2016 [GED Recipients] for African American Numerator',
#  'CBEC4X16R': '2016 [GED Recipients] for African American Rate',
#  'CAEC4X16N': '2016 [GED Recipients] for All Students Numerator',
#  'CAEC4X16R': '2016 [GED Recipients] for All Students Rate',
#  'CIEC4X16N': '2016 [GED Recipients] for American Indian Numerator',
#  'CIEC4X16R': '2016 [GED Recipients] for American Indian Rate',
#  'C3EC4X16N': '2016 [GED Recipients] for Asian Numerator',
#  'C3EC4X16R': '2016 [GED Recipients] for Asian Rate',
#  'CREC4X16N': '2016 [GED Recipients] for At Risk Numerator',
#  'CREC4X16R': '2016 [GED Recipients] for At Risk Rate',
#  'CEEC4X16N': '2016 [GED Recipients] for Econ Disadv Numerator',
#  'CEEC4X16R': '2016 [GED Recipients] for Econ Disadv Rate',
#  'CFEC4X16N': '2016 [GED Recipients] for Female Numerator',
#  'CFEC4X16R': '2016 [GED Recipients] for Female Rate',
#  'CHEC4X16N': '2016 [GED Recipients] for Hispanic Numerator',
#  'CHEC4X16R': '2016 [GED Recipients] for Hispanic Rate',
#  'CLEC4X16N': '2016 [GED Recipients] for LEP Numerator',
#  'CLEC4X16R': '2016 [GED Recipients] for LEP Rate',
#  'CMEC4X16N': '2016 [GED Recipients] for Male Numerator',
#  'CMEC4X16R': '2016 [GED Recipients] for Male Rate',
#  'C4EC4X16N': '2016 [GED Recipients] for Pacific Islander Numerator',
#  'C4EC4X16R': '2016 [GED Recipients] for Pacific Islander Rate',
#  'CSEC4X16N': '2016 [GED Recipients] for Special Ed Numerator',
#  'CSEC4X16R': '2016 [GED Recipients] for Special Ed Rate',
#  'C2EC4X16N': '2016 [GED Recipients] for Two or More Races Numerator',
#  'C2EC4X16R': '2016 [GED Recipients] for Two or More Races Rate',
#  'CWEC4X16N': '2016 [GED Recipients] for White Numerator',
#  'CWEC4X16R': '2016 [GED Recipients] for White Rate',
#  'CB2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for African American Numerator',
#  'CB2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for African American Rate',
#  'CA2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for All Students Numerator',
#  'CA2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for All Students Rate',
#  'CI2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for American Indian Numerator',
#  'CI2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for American Indian Rate',
#  'C32C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Asian Numerator',
#  'C32C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Asian Rate',
#  'CR2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for At Risk Numerator',
#  'CR2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for At Risk Rate',
#  'CE2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Econ Disadv Numerator',
#  'CE2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Econ Disadv Rate',
#  'CF2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Female Numerator',
#  'CF2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Female Rate',
#  'CH2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Hispanic Numerator',
#  'CH2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Hispanic Rate',
#  'CL2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for LEP Numerator',
#  'CL2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for LEP Rate',
#  'CM2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Male Numerator',
#  'CM2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Male Rate',
#  'C42C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Pacific Islander Numerator',
#  'C42C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Pacific Islander Rate',
#  'CS2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Special Ed Numerator',
#  'CS2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Special Ed Rate',
#  'C22C4X16N': '2016 [Graduates + GED Recipients + Continuers] for Two or More Races Numerator',
#  'C22C4X16R': '2016 [Graduates + GED Recipients + Continuers] for Two or More Races Rate',
#  'CW2C4X16N': '2016 [Graduates + GED Recipients + Continuers] for White Numerator',
#  'CW2C4X16R': '2016 [Graduates + GED Recipients + Continuers] for White Rate',
#  'CB3C4X16N': '2016 [Graduates + GED Recipients] for African American Numerator',
#  'CB3C4X16R': '2016 [Graduates + GED Recipients] for African American Rate',
#  'CA3C4X16N': '2016 [Graduates + GED Recipients] for All Students Numerator',
#  'CA3C4X16R': '2016 [Graduates + GED Recipients] for All Students Rate',
#  'CI3C4X16N': '2016 [Graduates + GED Recipients] for American Indian Numerator',
#  'CI3C4X16R': '2016 [Graduates + GED Recipients] for American Indian Rate',
#  'C33C4X16N': '2016 [Graduates + GED Recipients] for Asian Numerator',
#  'C33C4X16R': '2016 [Graduates + GED Recipients] for Asian Rate',
#  'CR3C4X16N': '2016 [Graduates + GED Recipients] for At Risk Numerator',
#  'CR3C4X16R': '2016 [Graduates + GED Recipients] for At Risk Rate',
#  'CE3C4X16N': '2016 [Graduates + GED Recipients] for Econ Disadv Numerator',
#  'CE3C4X16R': '2016 [Graduates + GED Recipients] for Econ Disadv Rate',
#  'CF3C4X16N': '2016 [Graduates + GED Recipients] for Female Numerator',
#  'CF3C4X16R': '2016 [Graduates + GED Recipients] for Female Rate',
#  'CH3C4X16N': '2016 [Graduates + GED Recipients] for Hispanic Numerator',
#  'CH3C4X16R': '2016 [Graduates + GED Recipients] for Hispanic Rate',
#  'CL3C4X16N': '2016 [Graduates + GED Recipients] for LEP Numerator',
#  'CL3C4X16R': '2016 [Graduates + GED Recipients] for LEP Rate',
#  'CM3C4X16N': '2016 [Graduates + GED Recipients] for Male Numerator',
#  'CM3C4X16R': '2016 [Graduates + GED Recipients] for Male Rate',
#  'C43C4X16N': '2016 [Graduates + GED Recipients] for Pacific Islander Numerator',
#  'C43C4X16R': '2016 [Graduates + GED Recipients] for Pacific Islander Rate',
#  'CS3C4X16N': '2016 [Graduates + GED Recipients] for Special Ed Numerator',
#  'CS3C4X16R': '2016 [Graduates + GED Recipients] for Special Ed Rate',
#  'C23C4X16N': '2016 [Graduates + GED Recipients] for Two or More Races Numerator',
#  'C23C4X16R': '2016 [Graduates + GED Recipients] for Two or More Races Rate',
#  'CW3C4X16N': '2016 [Graduates + GED Recipients] for White Numerator',
#  'CW3C4X16R': '2016 [Graduates + GED Recipients] for White Rate',
#  'CBGC4X16N': '2016 [Graduates] for African American Numerator',
#  'CBGC4X16R': '2016 [Graduates] for African American Rate',
#  'CAGC4X16N': '2016 [Graduates] for All Students Numerator',
#  'CAGC4X16R': '2016 [Graduates] for All Students Rate',
#  'CIGC4X16N': '2016 [Graduates] for American Indian Numerator',
#  'CIGC4X16R': '2016 [Graduates] for American Indian Rate',
#  'C3GC4X16N': '2016 [Graduates] for Asian Numerator',
#  'C3GC4X16R': '2016 [Graduates] for Asian Rate',
#  'CRGC4X16N': '2016 [Graduates] for At Risk Numerator',
#  'CRGC4X16R': '2016 [Graduates] for At Risk Rate',
#  'CEGC4X16N': '2016 [Graduates] for Econ Disadv Numerator',
#  'CEGC4X16R': '2016 [Graduates] for Econ Disadv Rate',
#  'CFGC4X16N': '2016 [Graduates] for Female Numerator',
#  'CFGC4X16R': '2016 [Graduates] for Female Rate',
#  'CHGC4X16N': '2016 [Graduates] for Hispanic Numerator',
#  'CHGC4X16R': '2016 [Graduates] for Hispanic Rate',
#  'CLGC4X16N': '2016 [Graduates] for LEP Numerator',
#  'CLGC4X16R': '2016 [Graduates] for LEP Rate',
#  'CMGC4X16N': '2016 [Graduates] for Male Numerator',
#  'CMGC4X16R': '2016 [Graduates] for Male Rate',
#  'C4GC4X16N': '2016 [Graduates] for Pacific Islander Numerator',
#  'C4GC4X16R': '2016 [Graduates] for Pacific Islander Rate',
#  'CSGC4X16N': '2016 [Graduates] for Special Ed Numerator',
#  'CSGC4X16R': '2016 [Graduates] for Special Ed Rate',
#  'C2GC4X16N': '2016 [Graduates] for Two or More Races Numerator',
#  'C2GC4X16R': '2016 [Graduates] for Two or More Races Rate',
#  'CWGC4X16N': '2016 [Graduates] for White Numerator',
#  'CWGC4X16R': '2016 [Graduates] for White Rate',
#  'CB0C4X17D': '2017 African American Denominator',
#  'CA0C4X17D': '2017 All Students Denominator',
#  'CI0C4X17D': '2017 American Indian Denominator',
#  'C30C4X17D': '2017 Asian Denominator',
#  'CR0C4X17D': '2017 At Risk Denominator',
#  'CE0C4X17D': '2017 Econ Disadv Denominator',
#  'CF0C4X17D': '2017 Female Denominator',
#  'CH0C4X17D': '2017 Hispanic Denominator',
#  'CL0C4X17D': '2017 LEP Denominator',
#  'CM0C4X17D': '2017 Male Denominator',
#  'C40C4X17D': '2017 Pacific Islander Denominator',
#  'CS0C4X17D': '2017 Special Ed Denominator',
#  'C20C4X17D': '2017 Two or More Races Denominator',
#  'CW0C4X17D': '2017 White Denominator',
#  'CBNC4X17N': '2017 [Continuers] for African American Numerator',
#  'CBNC4X17R': '2017 [Continuers] for African American Rate',
#  'CANC4X17N': '2017 [Continuers] for All Students Numerator',
#  'CANC4X17R': '2017 [Continuers] for All Students Rate',
#  'CINC4X17N': '2017 [Continuers] for American Indian Numerator',
#  'CINC4X17R': '2017 [Continuers] for American Indian Rate',
#  'C3NC4X17N': '2017 [Continuers] for Asian Numerator',
#  'C3NC4X17R': '2017 [Continuers] for Asian Rate',
#  'CRNC4X17N': '2017 [Continuers] for At Risk Numerator',
#  'CRNC4X17R': '2017 [Continuers] for At Risk Rate',
#  'CENC4X17N': '2017 [Continuers] for Econ Disadv Numerator',
#  'CENC4X17R': '2017 [Continuers] for Econ Disadv Rate',
#  'CFNC4X17N': '2017 [Continuers] for Female Numerator',
#  'CFNC4X17R': '2017 [Continuers] for Female Rate',
#  'CHNC4X17N': '2017 [Continuers] for Hispanic Numerator',
#  'CHNC4X17R': '2017 [Continuers] for Hispanic Rate',
#  'CLNC4X17N': '2017 [Continuers] for LEP Numerator',
#  'CLNC4X17R': '2017 [Continuers] for LEP Rate',
#  'CMNC4X17N': '2017 [Continuers] for Male Numerator',
#  'CMNC4X17R': '2017 [Continuers] for Male Rate',
#  'C4NC4X17N': '2017 [Continuers] for Pacific Islander Numerator',
#  'C4NC4X17R': '2017 [Continuers] for Pacific Islander Rate',
#  'CSNC4X17N': '2017 [Continuers] for Special Ed Numerator',
#  'CSNC4X17R': '2017 [Continuers] for Special Ed Rate',
#  'C2NC4X17N': '2017 [Continuers] for Two or More Races Numerator',
#  'C2NC4X17R': '2017 [Continuers] for Two or More Races Rate',
#  'CWNC4X17N': '2017 [Continuers] for White Numerator',
#  'CWNC4X17R': '2017 [Continuers] for White Rate',
#  'CBDC4X17N': '2017 [Dropout] for African American Numerator',
#  'CBDC4X17R': '2017 [Dropout] for African American Rate',
#  'CADC4X17N': '2017 [Dropout] for All Students Numerator',
#  'CADC4X17R': '2017 [Dropout] for All Students Rate',
#  'CIDC4X17N': '2017 [Dropout] for American Indian Numerator',
#  'CIDC4X17R': '2017 [Dropout] for American Indian Rate',
#  'C3DC4X17N': '2017 [Dropout] for Asian Numerator',
#  'C3DC4X17R': '2017 [Dropout] for Asian Rate',
#  'CRDC4X17N': '2017 [Dropout] for At Risk Numerator',
#  'CRDC4X17R': '2017 [Dropout] for At Risk Rate',
#  'CEDC4X17N': '2017 [Dropout] for Econ Disadv Numerator',
#  'CEDC4X17R': '2017 [Dropout] for Econ Disadv Rate',
#  'CFDC4X17N': '2017 [Dropout] for Female Numerator',
#  'CFDC4X17R': '2017 [Dropout] for Female Rate',
#  'CHDC4X17N': '2017 [Dropout] for Hispanic Numerator',
#  'CHDC4X17R': '2017 [Dropout] for Hispanic Rate',
#  'CLDC4X17N': '2017 [Dropout] for LEP Numerator',
#  'CLDC4X17R': '2017 [Dropout] for LEP Rate',
#  'CMDC4X17N': '2017 [Dropout] for Male Numerator',
#  'CMDC4X17R': '2017 [Dropout] for Male Rate',
#  'C4DC4X17N': '2017 [Dropout] for Pacific Islander Numerator',
#  'C4DC4X17R': '2017 [Dropout] for Pacific Islander Rate',
#  'CSDC4X17N': '2017 [Dropout] for Special Ed Numerator',
#  'CSDC4X17R': '2017 [Dropout] for Special Ed Rate',
#  'C2DC4X17N': '2017 [Dropout] for Two or More Races Numerator',
#  'C2DC4X17R': '2017 [Dropout] for Two or More Races Rate',
#  'CWDC4X17N': '2017 [Dropout] for White Numerator',
#  'CWDC4X17R': '2017 [Dropout] for White Rate',
#  'CB2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for African American Numerator',
#  'CB2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for African American Rate',
#  'CA2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for All Students Numerator',
#  'CA2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for All Students Rate',
#  'CI2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for American Indian Numerator',
#  'CI2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for American Indian Rate',
#  'C32C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Asian Numerator',
#  'C32C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Asian Rate',
#  'CR2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for At Risk Numerator',
#  'CR2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for At Risk Rate',
#  'CE2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Numerator',
#  'CE2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Rate',
#  'CF2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Female Numerator',
#  'CF2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Female Rate',
#  'CH2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Numerator',
#  'CH2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Rate',
#  'CL2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for LEP Numerator',
#  'CL2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for LEP Rate',
#  'CM2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Male Numerator',
#  'CM2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Male Rate',
#  'C42C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Numerator',
#  'C42C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Rate',
#  'CS2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Numerator',
#  'CS2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Rate',
#  'C22C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Numerator',
#  'C22C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Rate',
#  'CW2C4X17N': '2017 [Graduates + TxCHSE Recipients + Continuers] for White Numerator',
#  'CW2C4X17R': '2017 [Graduates + TxCHSE Recipients + Continuers] for White Rate',
#  'CB3C4X17N': '2017 [Graduates + TxCHSE Recipients] for African American Numerator',
#  'CB3C4X17R': '2017 [Graduates + TxCHSE Recipients] for African American Rate',
#  'CA3C4X17N': '2017 [Graduates + TxCHSE Recipients] for All Students Numerator',
#  'CA3C4X17R': '2017 [Graduates + TxCHSE Recipients] for All Students Rate',
#  'CI3C4X17N': '2017 [Graduates + TxCHSE Recipients] for American Indian Numerator',
#  'CI3C4X17R': '2017 [Graduates + TxCHSE Recipients] for American Indian Rate',
#  'C33C4X17N': '2017 [Graduates + TxCHSE Recipients] for Asian Numerator',
#  'C33C4X17R': '2017 [Graduates + TxCHSE Recipients] for Asian Rate',
#  'CR3C4X17N': '2017 [Graduates + TxCHSE Recipients] for At Risk Numerator',
#  'CR3C4X17R': '2017 [Graduates + TxCHSE Recipients] for At Risk Rate',
#  'CE3C4X17N': '2017 [Graduates + TxCHSE Recipients] for Econ Disadv Numerator',
#  'CE3C4X17R': '2017 [Graduates + TxCHSE Recipients] for Econ Disadv Rate',
#  'CF3C4X17N': '2017 [Graduates + TxCHSE Recipients] for Female Numerator',
#  'CF3C4X17R': '2017 [Graduates + TxCHSE Recipients] for Female Rate',
#  'CH3C4X17N': '2017 [Graduates + TxCHSE Recipients] for Hispanic Numerator',
#  'CH3C4X17R': '2017 [Graduates + TxCHSE Recipients] for Hispanic Rate',
#  'CL3C4X17N': '2017 [Graduates + TxCHSE Recipients] for LEP Numerator',
#  'CL3C4X17R': '2017 [Graduates + TxCHSE Recipients] for LEP Rate',
#  'CM3C4X17N': '2017 [Graduates + TxCHSE Recipients] for Male Numerator',
#  'CM3C4X17R': '2017 [Graduates + TxCHSE Recipients] for Male Rate',
#  'C43C4X17N': '2017 [Graduates + TxCHSE Recipients] for Pacific Islander Numerator',
#  'C43C4X17R': '2017 [Graduates + TxCHSE Recipients] for Pacific Islander Rate',
#  'CS3C4X17N': '2017 [Graduates + TxCHSE Recipients] for Special Ed Numerator',
#  'CS3C4X17R': '2017 [Graduates + TxCHSE Recipients] for Special Ed Rate',
#  'C23C4X17N': '2017 [Graduates + TxCHSE Recipients] for Two or More Races Numerator',
#  'C23C4X17R': '2017 [Graduates + TxCHSE Recipients] for Two or More Races Rate',
#  'CW3C4X17N': '2017 [Graduates + TxCHSE Recipients] for White Numerator',
#  'CW3C4X17R': '2017 [Graduates + TxCHSE Recipients] for White Rate',
#  'CBGC4X17N': '2017 [Graduates] for African American Numerator',
#  'CBGC4X17R': '2017 [Graduates] for African American Rate',
#  'CAGC4X17N': '2017 [Graduates] for All Students Numerator',
#  'CAGC4X17R': '2017 [Graduates] for All Students Rate',
#  'CIGC4X17N': '2017 [Graduates] for American Indian Numerator',
#  'CIGC4X17R': '2017 [Graduates] for American Indian Rate',
#  'C3GC4X17N': '2017 [Graduates] for Asian Numerator',
#  'C3GC4X17R': '2017 [Graduates] for Asian Rate',
#  'CRGC4X17N': '2017 [Graduates] for At Risk Numerator',
#  'CRGC4X17R': '2017 [Graduates] for At Risk Rate',
#  'CEGC4X17N': '2017 [Graduates] for Econ Disadv Numerator',
#  'CEGC4X17R': '2017 [Graduates] for Econ Disadv Rate',
#  'CFGC4X17N': '2017 [Graduates] for Female Numerator',
#  'CFGC4X17R': '2017 [Graduates] for Female Rate',
#  'CHGC4X17N': '2017 [Graduates] for Hispanic Numerator',
#  'CHGC4X17R': '2017 [Graduates] for Hispanic Rate',
#  'CLGC4X17N': '2017 [Graduates] for LEP Numerator',
#  'CLGC4X17R': '2017 [Graduates] for LEP Rate',
#  'CMGC4X17N': '2017 [Graduates] for Male Numerator',
#  'CMGC4X17R': '2017 [Graduates] for Male Rate',
#  'C4GC4X17N': '2017 [Graduates] for Pacific Islander Numerator',
#  'C4GC4X17R': '2017 [Graduates] for Pacific Islander Rate',
#  'CSGC4X17N': '2017 [Graduates] for Special Ed Numerator',
#  'CSGC4X17R': '2017 [Graduates] for Special Ed Rate',
#  'C2GC4X17N': '2017 [Graduates] for Two or More Races Numerator',
#  'C2GC4X17R': '2017 [Graduates] for Two or More Races Rate',
#  'CWGC4X17N': '2017 [Graduates] for White Numerator',
#  'CWGC4X17R': '2017 [Graduates] for White Rate',
#  'CBEC4X17N': '2017 [TxCHSE Recipients] for African American Numerator',
#  'CBEC4X17R': '2017 [TxCHSE Recipients] for African American Rate',
#  'CAEC4X17N': '2017 [TxCHSE Recipients] for All Students Numerator',
#  'CAEC4X17R': '2017 [TxCHSE Recipients] for All Students Rate',
#  'CIEC4X17N': '2017 [TxCHSE Recipients] for American Indian Numerator',
#  'CIEC4X17R': '2017 [TxCHSE Recipients] for American Indian Rate',
#  'C3EC4X17N': '2017 [TxCHSE Recipients] for Asian Numerator',
#  'C3EC4X17R': '2017 [TxCHSE Recipients] for Asian Rate',
#  'CREC4X17N': '2017 [TxCHSE Recipients] for At Risk Numerator',
#  'CREC4X17R': '2017 [TxCHSE Recipients] for At Risk Rate',
#  'CEEC4X17N': '2017 [TxCHSE Recipients] for Econ Disadv Numerator',
#  'CEEC4X17R': '2017 [TxCHSE Recipients] for Econ Disadv Rate',
#  'CFEC4X17N': '2017 [TxCHSE Recipients] for Female Numerator',
#  'CFEC4X17R': '2017 [TxCHSE Recipients] for Female Rate',
#  'CHEC4X17N': '2017 [TxCHSE Recipients] for Hispanic Numerator',
#  'CHEC4X17R': '2017 [TxCHSE Recipients] for Hispanic Rate',
#  'CLEC4X17N': '2017 [TxCHSE Recipients] for LEP Numerator',
#  'CLEC4X17R': '2017 [TxCHSE Recipients] for LEP Rate',
#  'CMEC4X17N': '2017 [TxCHSE Recipients] for Male Numerator',
#  'CMEC4X17R': '2017 [TxCHSE Recipients] for Male Rate',
#  'C4EC4X17N': '2017 [TxCHSE Recipients] for Pacific Islander Numerator',
#  'C4EC4X17R': '2017 [TxCHSE Recipients] for Pacific Islander Rate',
#  'CSEC4X17N': '2017 [TxCHSE Recipients] for Special Ed Numerator',
#  'CSEC4X17R': '2017 [TxCHSE Recipients] for Special Ed Rate',
#  'C2EC4X17N': '2017 [TxCHSE Recipients] for Two or More Races Numerator',
#  'C2EC4X17R': '2017 [TxCHSE Recipients] for Two or More Races Rate',
#  'CWEC4X17N': '2017 [TxCHSE Recipients] for White Numerator',
#  'CWEC4X17R': '2017 [TxCHSE Recipients] for White Rate',
#  'CB0C416D': '2016 African American Denominator (Federal Graduation without Exclusions)',
#  'CA0C416D': '2016 All Students Denominator (Federal Graduation without Exclusions)',
#  'CI0C416D': '2016 American Indian Denominator (Federal Graduation without Exclusions)',
#  'C30C416D': '2016 Asian Denominator (Federal Graduation without Exclusions)',
#  'CR0C416D': '2016 At Risk Denominator (Federal Graduation without Exclusions)',
#  'CE0C416D': '2016 Econ Disadv Denominator (Federal Graduation without Exclusions)',
#  'CF0C416D': '2016 Female Denominator (Federal Graduation without Exclusions)',
#  'CH0C416D': '2016 Hispanic Denominator (Federal Graduation without Exclusions)',
#  'CL0C416D': '2016 LEP Denominator (Federal Graduation without Exclusions)',
#  'CM0C416D': '2016 Male Denominator (Federal Graduation without Exclusions)',
#  'C40C416D': '2016 Pacific Islander Denominator (Federal Graduation without Exclusions)',
#  'CS0C416D': '2016 Special Ed Denominator (Federal Graduation without Exclusions)',
#  'C20C416D': '2016 Two or More Races Denominator (Federal Graduation without Exclusions)',
#  'CW0C416D': '2016 White Denominator (Federal Graduation without Exclusions)',
#  'CBGC416N': '2016 [Graduates] for African American Numerator (Federal Graduation without Exclusions)',
#  'CBGC416R': '2016 [Graduates] for African American Rate (Federal Graduation without Exclusions)',
#  'CAGC416N': '2016 [Graduates] for All Students Numerator (Federal Graduation without Exclusions)',
#  'CAGC416R': '2016 [Graduates] for All Students Rate (Federal Graduation without Exclusions)',
#  'CIGC416N': '2016 [Graduates] for American Indian Numerator (Federal Graduation without Exclusions)',
#  'CIGC416R': '2016 [Graduates] for American Indian Rate (Federal Graduation without Exclusions)',
#  'C3GC416N': '2016 [Graduates] for Asian Numerator (Federal Graduation without Exclusions)',
#  'C3GC416R': '2016 [Graduates] for Asian Rate (Federal Graduation without Exclusions)',
#  'CRGC416N': '2016 [Graduates] for At Risk Numerator (Federal Graduation without Exclusions)',
#  'CRGC416R': '2016 [Graduates] for At Risk Rate (Federal Graduation without Exclusions)',
#  'CEGC416N': '2016 [Graduates] for Econ Disadv Numerator (Federal Graduation without Exclusions)',
#  'CEGC416R': '2016 [Graduates] for Econ Disadv Rate (Federal Graduation without Exclusions)',
#  'CFGC416N': '2016 [Graduates] for Female Numerator (Federal Graduation without Exclusions)',
#  'CFGC416R': '2016 [Graduates] for Female Rate (Federal Graduation without Exclusions)',
#  'CHGC416N': '2016 [Graduates] for Hispanic Numerator (Federal Graduation without Exclusions)',
#  'CHGC416R': '2016 [Graduates] for Hispanic Rate (Federal Graduation without Exclusions)',
#  'CLGC416N': '2016 [Graduates] for LEP Numerator (Federal Graduation without Exclusions)',
#  'CLGC416R': '2016 [Graduates] for LEP Rate (Federal Graduation without Exclusions)',
#  'CMGC416N': '2016 [Graduates] for Male Numerator (Federal Graduation without Exclusions)',
#  'CMGC416R': '2016 [Graduates] for Male Rate (Federal Graduation without Exclusions)',
#  'C4GC416N': '2016 [Graduates] for Pacific Islander Numerator (Federal Graduation without Exclusions)',
#  'C4GC416R': '2016 [Graduates] for Pacific Islander Rate (Federal Graduation without Exclusions)',
#  'CSGC416N': '2016 [Graduates] for Special Ed Numerator (Federal Graduation without Exclusions)',
#  'CSGC416R': '2016 [Graduates] for Special Ed Rate (Federal Graduation without Exclusions)',
#  'C2GC416N': '2016 [Graduates] for Two or More Races Numerator (Federal Graduation without Exclusions)',
#  'C2GC416R': '2016 [Graduates] for Two or More Races Rate (Federal Graduation without Exclusions)',
#  'CWGC416N': '2016 [Graduates] for White Numerator (Federal Graduation without Exclusions)',
#  'CWGC416R': '2016 [Graduates] for White Rate (Federal Graduation without Exclusions)',
#  'CB0C417D': '2017 African American Denominator (Federal Graduation without Exclusions)',
#  'CA0C417D': '2017 All Students Denominator (Federal Graduation without Exclusions)',
#  'CI0C417D': '2017 American Indian Denominator (Federal Graduation without Exclusions)',
#  'C30C417D': '2017 Asian Denominator (Federal Graduation without Exclusions)',
#  'CR0C417D': '2017 At Risk Denominator (Federal Graduation without Exclusions)',
#  'CE0C417D': '2017 Econ Disadv Denominator (Federal Graduation without Exclusions)',
#  'CF0C417D': '2017 Female Denominator (Federal Graduation without Exclusions)',
#  'CH0C417D': '2017 Hispanic Denominator (Federal Graduation without Exclusions)',
#  'CL0C417D': '2017 LEP Denominator (Federal Graduation without Exclusions)',
#  'CM0C417D': '2017 Male Denominator (Federal Graduation without Exclusions)',
#  'C40C417D': '2017 Pacific Islander Denominator (Federal Graduation without Exclusions)',
#  'CS0C417D': '2017 Special Ed Denominator (Federal Graduation without Exclusions)',
#  'C20C417D': '2017 Two or More Races Denominator (Federal Graduation without Exclusions)',
#  'CW0C417D': '2017 White Denominator (Federal Graduation without Exclusions)',
#  'CBGC417N': '2017 [Graduates] for African American Numerator (Federal Graduation without Exclusions)',
#  'CBGC417R': '2017 [Graduates] for African American Rate (Federal Graduation without Exclusions)',
#  'CAGC417N': '2017 [Graduates] for All Students Numerator (Federal Graduation without Exclusions)',
#  'CAGC417R': '2017 [Graduates] for All Students Rate (Federal Graduation without Exclusions)',
#  'CIGC417N': '2017 [Graduates] for American Indian Numerator (Federal Graduation without Exclusions)',
#  'CIGC417R': '2017 [Graduates] for American Indian Rate (Federal Graduation without Exclusions)',
#  'C3GC417N': '2017 [Graduates] for Asian Numerator (Federal Graduation without Exclusions)',
#  'C3GC417R': '2017 [Graduates] for Asian Rate (Federal Graduation without Exclusions)',
#  'CRGC417N': '2017 [Graduates] for At Risk Numerator (Federal Graduation without Exclusions)',
#  'CRGC417R': '2017 [Graduates] for At Risk Rate (Federal Graduation without Exclusions)',
#  'CEGC417N': '2017 [Graduates] for Econ Disadv Numerator (Federal Graduation without Exclusions)',
#  'CEGC417R': '2017 [Graduates] for Econ Disadv Rate (Federal Graduation without Exclusions)',
#  'CFGC417N': '2017 [Graduates] for Female Numerator (Federal Graduation without Exclusions)',
#  'CFGC417R': '2017 [Graduates] for Female Rate (Federal Graduation without Exclusions)',
#  'CHGC417N': '2017 [Graduates] for Hispanic Numerator (Federal Graduation without Exclusions)',
#  'CHGC417R': '2017 [Graduates] for Hispanic Rate (Federal Graduation without Exclusions)',
#  'CLGC417N': '2017 [Graduates] for LEP Numerator (Federal Graduation without Exclusions)',
#  'CLGC417R': '2017 [Graduates] for LEP Rate (Federal Graduation without Exclusions)',
#  'CMGC417N': '2017 [Graduates] for Male Numerator (Federal Graduation without Exclusions)',
#  'CMGC417R': '2017 [Graduates] for Male Rate (Federal Graduation without Exclusions)',
#  'C4GC417N': '2017 [Graduates] for Pacific Islander Numerator (Federal Graduation without Exclusions)',
#  'C4GC417R': '2017 [Graduates] for Pacific Islander Rate (Federal Graduation without Exclusions)',
#  'CSGC417N': '2017 [Graduates] for Special Ed Numerator (Federal Graduation without Exclusions)',
#  'CSGC417R': '2017 [Graduates] for Special Ed Rate (Federal Graduation without Exclusions)',
#  'C2GC417N': '2017 [Graduates] for Two or More Races Numerator (Federal Graduation without Exclusions)',
#  'C2GC417R': '2017 [Graduates] for Two or More Races Rate (Federal Graduation without Exclusions)',
#  'CWGC417N': '2017 [Graduates] for White Numerator (Federal Graduation without Exclusions)',
#  'CWGC417R': '2017 [Graduates] for White Rate (Federal Graduation without Exclusions)',
#  'CB0C4X19D': '2019 African American Denominator',
#  'CA0C4X19D': '2019 All Students Denominator',
#  'CI0C4X19D': '2019 American Indian Denominator',
#  'C30C4X19D': '2019 Asian Denominator',
#  'CR0C4X19D': '2019 At Risk Denominator',
#  'CL0C4X19D': '2019 EL Denominator',
#  'CE0C4X19D': '2019 Econ Disadv Denominator',
#  'CF0C4X19D': '2019 Female Denominator',
#  'CH0C4X19D': '2019 Hispanic Denominator',
#  'CM0C4X19D': '2019 Male Denominator',
#  'C40C4X19D': '2019 Pacific Islander Denominator',
#  'CS0C4X19D': '2019 Special Ed Denominator',
#  'C20C4X19D': '2019 Two or More Races Denominator',
#  'CW0C4X19D': '2019 White Denominator',
#  'CBNC4X19N': '2019 [Continuers] for African American Numerator',
#  'CBNC4X19R': '2019 [Continuers] for African American Rate',
#  'CANC4X19N': '2019 [Continuers] for All Students Numerator',
#  'CANC4X19R': '2019 [Continuers] for All Students Rate',
#  'CINC4X19N': '2019 [Continuers] for American Indian Numerator',
#  'CINC4X19R': '2019 [Continuers] for American Indian Rate',
#  'C3NC4X19N': '2019 [Continuers] for Asian Numerator',
#  'C3NC4X19R': '2019 [Continuers] for Asian Rate',
#  'CRNC4X19N': '2019 [Continuers] for At Risk Numerator',
#  'CRNC4X19R': '2019 [Continuers] for At Risk Rate',
#  'CLNC4X19N': '2019 [Continuers] for EL Numerator',
#  'CLNC4X19R': '2019 [Continuers] for EL Rate',
#  'CENC4X19N': '2019 [Continuers] for Econ Disadv Numerator',
#  'CENC4X19R': '2019 [Continuers] for Econ Disadv Rate',
#  'CFNC4X19N': '2019 [Continuers] for Female Numerator',
#  'CFNC4X19R': '2019 [Continuers] for Female Rate',
#  'CHNC4X19N': '2019 [Continuers] for Hispanic Numerator',
#  'CHNC4X19R': '2019 [Continuers] for Hispanic Rate',
#  'CMNC4X19N': '2019 [Continuers] for Male Numerator',
#  'CMNC4X19R': '2019 [Continuers] for Male Rate',
#  'C4NC4X19N': '2019 [Continuers] for Pacific Islander Numerator',
#  'C4NC4X19R': '2019 [Continuers] for Pacific Islander Rate',
#  'CSNC4X19N': '2019 [Continuers] for Special Ed Numerator',
#  'CSNC4X19R': '2019 [Continuers] for Special Ed Rate',
#  'C2NC4X19N': '2019 [Continuers] for Two or More Races Numerator',
#  'C2NC4X19R': '2019 [Continuers] for Two or More Races Rate',
#  'CWNC4X19N': '2019 [Continuers] for White Numerator',
#  'CWNC4X19R': '2019 [Continuers] for White Rate',
#  'CBDC4X19N': '2019 [Dropout] for African American Numerator',
#  'CBDC4X19R': '2019 [Dropout] for African American Rate',
#  'CADC4X19N': '2019 [Dropout] for All Students Numerator',
#  'CADC4X19R': '2019 [Dropout] for All Students Rate',
#  'CIDC4X19N': '2019 [Dropout] for American Indian Numerator',
#  'CIDC4X19R': '2019 [Dropout] for American Indian Rate',
#  'C3DC4X19N': '2019 [Dropout] for Asian Numerator',
#  'C3DC4X19R': '2019 [Dropout] for Asian Rate',
#  'CRDC4X19N': '2019 [Dropout] for At Risk Numerator',
#  'CRDC4X19R': '2019 [Dropout] for At Risk Rate',
#  'CLDC4X19N': '2019 [Dropout] for EL Numerator',
#  'CLDC4X19R': '2019 [Dropout] for EL Rate',
#  'CEDC4X19N': '2019 [Dropout] for Econ Disadv Numerator',
#  'CEDC4X19R': '2019 [Dropout] for Econ Disadv Rate',
#  'CFDC4X19N': '2019 [Dropout] for Female Numerator',
#  'CFDC4X19R': '2019 [Dropout] for Female Rate',
#  'CHDC4X19N': '2019 [Dropout] for Hispanic Numerator',
#  'CHDC4X19R': '2019 [Dropout] for Hispanic Rate',
#  'CMDC4X19N': '2019 [Dropout] for Male Numerator',
#  'CMDC4X19R': '2019 [Dropout] for Male Rate',
#  'C4DC4X19N': '2019 [Dropout] for Pacific Islander Numerator',
#  'C4DC4X19R': '2019 [Dropout] for Pacific Islander Rate',
#  'CSDC4X19N': '2019 [Dropout] for Special Ed Numerator',
#  'CSDC4X19R': '2019 [Dropout] for Special Ed Rate',
#  'C2DC4X19N': '2019 [Dropout] for Two or More Races Numerator',
#  'C2DC4X19R': '2019 [Dropout] for Two or More Races Rate',
#  'CWDC4X19N': '2019 [Dropout] for White Numerator',
#  'CWDC4X19R': '2019 [Dropout] for White Rate',
#  'CB2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for African American Numerator',
#  'CB2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for African American Rate',
#  'CA2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for All Students Numerator',
#  'CA2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for All Students Rate',
#  'CI2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for American Indian Numerator',
#  'CI2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for American Indian Rate',
#  'C32C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Asian Numerator',
#  'C32C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Asian Rate',
#  'CR2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for At Risk Numerator',
#  'CR2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for At Risk Rate',
#  'CL2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for EL Numerator',
#  'CL2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for EL Rate',
#  'CE2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Numerator',
#  'CE2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Rate',
#  'CF2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Female Numerator',
#  'CF2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Female Rate',
#  'CH2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Numerator',
#  'CH2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Rate',
#  'CM2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Male Numerator',
#  'CM2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Male Rate',
#  'C42C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Numerator',
#  'C42C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Rate',
#  'CS2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Numerator',
#  'CS2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Rate',
#  'C22C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Numerator',
#  'C22C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Rate',
#  'CW2C4X19N': '2019 [Graduates + TxCHSE Recipients + Continuers] for White Numerator',
#  'CW2C4X19R': '2019 [Graduates + TxCHSE Recipients + Continuers] for White Rate',
#  'CB3C4X19N': '2019 [Graduates + TxCHSE Recipients] for African American Numerator',
#  'CB3C4X19R': '2019 [Graduates + TxCHSE Recipients] for African American Rate',
#  'CA3C4X19N': '2019 [Graduates + TxCHSE Recipients] for All Students Numerator',
#  'CA3C4X19R': '2019 [Graduates + TxCHSE Recipients] for All Students Rate',
#  'CI3C4X19N': '2019 [Graduates + TxCHSE Recipients] for American Indian Numerator',
#  'CI3C4X19R': '2019 [Graduates + TxCHSE Recipients] for American Indian Rate',
#  'C33C4X19N': '2019 [Graduates + TxCHSE Recipients] for Asian Numerator',
#  'C33C4X19R': '2019 [Graduates + TxCHSE Recipients] for Asian Rate',
#  'CR3C4X19N': '2019 [Graduates + TxCHSE Recipients] for At Risk Numerator',
#  'CR3C4X19R': '2019 [Graduates + TxCHSE Recipients] for At Risk Rate',
#  'CL3C4X19N': '2019 [Graduates + TxCHSE Recipients] for EL Numerator',
#  'CL3C4X19R': '2019 [Graduates + TxCHSE Recipients] for EL Rate',
#  'CE3C4X19N': '2019 [Graduates + TxCHSE Recipients] for Econ Disadv Numerator',
#  'CE3C4X19R': '2019 [Graduates + TxCHSE Recipients] for Econ Disadv Rate',
#  'CF3C4X19N': '2019 [Graduates + TxCHSE Recipients] for Female Numerator',
#  'CF3C4X19R': '2019 [Graduates + TxCHSE Recipients] for Female Rate',
#  'CH3C4X19N': '2019 [Graduates + TxCHSE Recipients] for Hispanic Numerator',
#  'CH3C4X19R': '2019 [Graduates + TxCHSE Recipients] for Hispanic Rate',
#  'CM3C4X19N': '2019 [Graduates + TxCHSE Recipients] for Male Numerator',
#  'CM3C4X19R': '2019 [Graduates + TxCHSE Recipients] for Male Rate',
#  'C43C4X19N': '2019 [Graduates + TxCHSE Recipients] for Pacific Islander Numerator',
#  'C43C4X19R': '2019 [Graduates + TxCHSE Recipients] for Pacific Islander Rate',
#  'CS3C4X19N': '2019 [Graduates + TxCHSE Recipients] for Special Ed Numerator',
#  'CS3C4X19R': '2019 [Graduates + TxCHSE Recipients] for Special Ed Rate',
#  'C23C4X19N': '2019 [Graduates + TxCHSE Recipients] for Two or More Races Numerator',
#  'C23C4X19R': '2019 [Graduates + TxCHSE Recipients] for Two or More Races Rate',
#  'CW3C4X19N': '2019 [Graduates + TxCHSE Recipients] for White Numerator',
#  'CW3C4X19R': '2019 [Graduates + TxCHSE Recipients] for White Rate',
#  'CBGC4X19N': '2019 [Graduates] for African American Numerator',
#  'CBGC4X19R': '2019 [Graduates] for African American Rate',
#  'CAGC4X19N': '2019 [Graduates] for All Students Numerator',
#  'CAGC4X19R': '2019 [Graduates] for All Students Rate',
#  'CIGC4X19N': '2019 [Graduates] for American Indian Numerator',
#  'CIGC4X19R': '2019 [Graduates] for American Indian Rate',
#  'C3GC4X19N': '2019 [Graduates] for Asian Numerator',
#  'C3GC4X19R': '2019 [Graduates] for Asian Rate',
#  'CRGC4X19N': '2019 [Graduates] for At Risk Numerator',
#  'CRGC4X19R': '2019 [Graduates] for At Risk Rate',
#  'CLGC4X19N': '2019 [Graduates] for EL Numerator',
#  'CLGC4X19R': '2019 [Graduates] for EL Rate',
#  'CEGC4X19N': '2019 [Graduates] for Econ Disadv Numerator',
#  'CEGC4X19R': '2019 [Graduates] for Econ Disadv Rate',
#  'CFGC4X19N': '2019 [Graduates] for Female Numerator',
#  'CFGC4X19R': '2019 [Graduates] for Female Rate',
#  'CHGC4X19N': '2019 [Graduates] for Hispanic Numerator',
#  'CHGC4X19R': '2019 [Graduates] for Hispanic Rate',
#  'CMGC4X19N': '2019 [Graduates] for Male Numerator',
#  'CMGC4X19R': '2019 [Graduates] for Male Rate',
#  'C4GC4X19N': '2019 [Graduates] for Pacific Islander Numerator',
#  'C4GC4X19R': '2019 [Graduates] for Pacific Islander Rate',
#  'CSGC4X19N': '2019 [Graduates] for Special Ed Numerator',
#  'CSGC4X19R': '2019 [Graduates] for Special Ed Rate',
#  'C2GC4X19N': '2019 [Graduates] for Two or More Races Numerator',
#  'C2GC4X19R': '2019 [Graduates] for Two or More Races Rate',
#  'CWGC4X19N': '2019 [Graduates] for White Numerator',
#  'CWGC4X19R': '2019 [Graduates] for White Rate',
#  'CBEC4X19N': '2019 [TxCHSE Recipients] for African American Numerator',
#  'CBEC4X19R': '2019 [TxCHSE Recipients] for African American Rate',
#  'CAEC4X19N': '2019 [TxCHSE Recipients] for All Students Numerator',
#  'CAEC4X19R': '2019 [TxCHSE Recipients] for All Students Rate',
#  'CIEC4X19N': '2019 [TxCHSE Recipients] for American Indian Numerator',
#  'CIEC4X19R': '2019 [TxCHSE Recipients] for American Indian Rate',
#  'C3EC4X19N': '2019 [TxCHSE Recipients] for Asian Numerator',
#  'C3EC4X19R': '2019 [TxCHSE Recipients] for Asian Rate',
#  'CREC4X19N': '2019 [TxCHSE Recipients] for At Risk Numerator',
#  'CREC4X19R': '2019 [TxCHSE Recipients] for At Risk Rate',
#  'CLEC4X19N': '2019 [TxCHSE Recipients] for EL Numerator',
#  'CLEC4X19R': '2019 [TxCHSE Recipients] for EL Rate',
#  'CEEC4X19N': '2019 [TxCHSE Recipients] for Econ Disadv Numerator',
#  'CEEC4X19R': '2019 [TxCHSE Recipients] for Econ Disadv Rate',
#  'CFEC4X19N': '2019 [TxCHSE Recipients] for Female Numerator',
#  'CFEC4X19R': '2019 [TxCHSE Recipients] for Female Rate',
#  'CHEC4X19N': '2019 [TxCHSE Recipients] for Hispanic Numerator',
#  'CHEC4X19R': '2019 [TxCHSE Recipients] for Hispanic Rate',
#  'CMEC4X19N': '2019 [TxCHSE Recipients] for Male Numerator',
#  'CMEC4X19R': '2019 [TxCHSE Recipients] for Male Rate',
#  'C4EC4X19N': '2019 [TxCHSE Recipients] for Pacific Islander Numerator',
#  'C4EC4X19R': '2019 [TxCHSE Recipients] for Pacific Islander Rate',
#  'CSEC4X19N': '2019 [TxCHSE Recipients] for Special Ed Numerator',
#  'CSEC4X19R': '2019 [TxCHSE Recipients] for Special Ed Rate',
#  'C2EC4X19N': '2019 [TxCHSE Recipients] for Two or More Races Numerator',
#  'C2EC4X19R': '2019 [TxCHSE Recipients] for Two or More Races Rate',
#  'CWEC4X19N': '2019 [TxCHSE Recipients] for White Numerator',
#  'CWEC4X19R': '2019 [TxCHSE Recipients] for White Rate',
#  'CB0C4X20D': '2020 African American Denominator',
#  'CA0C4X20D': '2020 All Students Denominator',
#  'CI0C4X20D': '2020 American Indian Denominator',
#  'C30C4X20D': '2020 Asian Denominator',
#  'CR0C4X20D': '2020 At Risk Denominator',
#  'CL0C4X20D': '2020 EL Denominator',
#  'CE0C4X20D': '2020 Econ Disadv Denominator',
#  'CF0C4X20D': '2020 Female Denominator',
#  'CH0C4X20D': '2020 Hispanic Denominator',
#  'CM0C4X20D': '2020 Male Denominator',
#  'C40C4X20D': '2020 Pacific Islander Denominator',
#  'CS0C4X20D': '2020 Special Ed Denominator',
#  'C20C4X20D': '2020 Two or More Races Denominator',
#  'CW0C4X20D': '2020 White Denominator',
#  'CBNC4X20N': '2020 [Continuers] for African American Numerator',
#  'CBNC4X20R': '2020 [Continuers] for African American Rate',
#  'CANC4X20N': '2020 [Continuers] for All Students Numerator',
#  'CANC4X20R': '2020 [Continuers] for All Students Rate',
#  'CINC4X20N': '2020 [Continuers] for American Indian Numerator',
#  'CINC4X20R': '2020 [Continuers] for American Indian Rate',
#  'C3NC4X20N': '2020 [Continuers] for Asian Numerator',
#  'C3NC4X20R': '2020 [Continuers] for Asian Rate',
#  'CRNC4X20N': '2020 [Continuers] for At Risk Numerator',
#  'CRNC4X20R': '2020 [Continuers] for At Risk Rate',
#  'CLNC4X20N': '2020 [Continuers] for EL Numerator',
#  'CLNC4X20R': '2020 [Continuers] for EL Rate',
#  'CENC4X20N': '2020 [Continuers] for Econ Disadv Numerator',
#  'CENC4X20R': '2020 [Continuers] for Econ Disadv Rate',
#  'CFNC4X20N': '2020 [Continuers] for Female Numerator',
#  'CFNC4X20R': '2020 [Continuers] for Female Rate',
#  'CHNC4X20N': '2020 [Continuers] for Hispanic Numerator',
#  'CHNC4X20R': '2020 [Continuers] for Hispanic Rate',
#  'CMNC4X20N': '2020 [Continuers] for Male Numerator',
#  'CMNC4X20R': '2020 [Continuers] for Male Rate',
#  'C4NC4X20N': '2020 [Continuers] for Pacific Islander Numerator',
#  'C4NC4X20R': '2020 [Continuers] for Pacific Islander Rate',
#  'CSNC4X20N': '2020 [Continuers] for Special Ed Numerator',
#  'CSNC4X20R': '2020 [Continuers] for Special Ed Rate',
#  'C2NC4X20N': '2020 [Continuers] for Two or More Races Numerator',
#  'C2NC4X20R': '2020 [Continuers] for Two or More Races Rate',
#  'CWNC4X20N': '2020 [Continuers] for White Numerator',
#  'CWNC4X20R': '2020 [Continuers] for White Rate',
#  'CBDC4X20N': '2020 [Dropout] for African American Numerator',
#  'CBDC4X20R': '2020 [Dropout] for African American Rate',
#  'CADC4X20N': '2020 [Dropout] for All Students Numerator',
#  'CADC4X20R': '2020 [Dropout] for All Students Rate',
#  'CIDC4X20N': '2020 [Dropout] for American Indian Numerator',
#  'CIDC4X20R': '2020 [Dropout] for American Indian Rate',
#  'C3DC4X20N': '2020 [Dropout] for Asian Numerator',
#  'C3DC4X20R': '2020 [Dropout] for Asian Rate',
#  'CRDC4X20N': '2020 [Dropout] for At Risk Numerator',
#  'CRDC4X20R': '2020 [Dropout] for At Risk Rate',
#  'CLDC4X20N': '2020 [Dropout] for EL Numerator',
#  'CLDC4X20R': '2020 [Dropout] for EL Rate',
#  'CEDC4X20N': '2020 [Dropout] for Econ Disadv Numerator',
#  'CEDC4X20R': '2020 [Dropout] for Econ Disadv Rate',
#  'CFDC4X20N': '2020 [Dropout] for Female Numerator',
#  'CFDC4X20R': '2020 [Dropout] for Female Rate',
#  'CHDC4X20N': '2020 [Dropout] for Hispanic Numerator',
#  'CHDC4X20R': '2020 [Dropout] for Hispanic Rate',
#  'CMDC4X20N': '2020 [Dropout] for Male Numerator',
#  'CMDC4X20R': '2020 [Dropout] for Male Rate',
#  'C4DC4X20N': '2020 [Dropout] for Pacific Islander Numerator',
#  'C4DC4X20R': '2020 [Dropout] for Pacific Islander Rate',
#  'CSDC4X20N': '2020 [Dropout] for Special Ed Numerator',
#  'CSDC4X20R': '2020 [Dropout] for Special Ed Rate',
#  'C2DC4X20N': '2020 [Dropout] for Two or More Races Numerator',
#  'C2DC4X20R': '2020 [Dropout] for Two or More Races Rate',
#  'CWDC4X20N': '2020 [Dropout] for White Numerator',
#  'CWDC4X20R': '2020 [Dropout] for White Rate',
#  'CB2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for African American Numerator',
#  'CB2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for African American Rate',
#  'CA2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for All Students Numerator',
#  'CA2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for All Students Rate',
#  'CI2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for American Indian Numerator',
#  'CI2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for American Indian Rate',
#  'C32C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Asian Numerator',
#  'C32C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Asian Rate',
#  'CR2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for At Risk Numerator',
#  'CR2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for At Risk Rate',
#  'CL2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for EL Numerator',
#  'CL2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for EL Rate',
#  'CE2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Numerator',
#  'CE2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Econ Disadv Rate',
#  'CF2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Female Numerator',
#  'CF2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Female Rate',
#  'CH2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Numerator',
#  'CH2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Rate',
#  'CM2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Male Numerator',
#  'CM2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Male Rate',
#  'C42C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Numerator',
#  'C42C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Rate',
#  'CS2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Numerator',
#  'CS2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Special Ed Rate',
#  'C22C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Numerator',
#  'C22C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Rate',
#  'CW2C4X20N': '2020 [Graduates + TxCHSE Recipients + Continuers] for White Numerator',
#  'CW2C4X20R': '2020 [Graduates + TxCHSE Recipients + Continuers] for White Rate',
#  'CB3C4X20N': '2020 [Graduates + TxCHSE Recipients] for African American Numerator',
#  'CB3C4X20R': '2020 [Graduates + TxCHSE Recipients] for African American Rate',
#  'CA3C4X20N': '2020 [Graduates + TxCHSE Recipients] for All Students Numerator',
#  'CA3C4X20R': '2020 [Graduates + TxCHSE Recipients] for All Students Rate',
#  'CI3C4X20N': '2020 [Graduates + TxCHSE Recipients] for American Indian Numerator',
#  'CI3C4X20R': '2020 [Graduates + TxCHSE Recipients] for American Indian Rate',
#  'C33C4X20N': '2020 [Graduates + TxCHSE Recipients] for Asian Numerator',
#  'C33C4X20R': '2020 [Graduates + TxCHSE Recipients] for Asian Rate',
#  'CR3C4X20N': '2020 [Graduates + TxCHSE Recipients] for At Risk Numerator',
#  'CR3C4X20R': '2020 [Graduates + TxCHSE Recipients] for At Risk Rate',
#  'CL3C4X20N': '2020 [Graduates + TxCHSE Recipients] for EL Numerator',
#  'CL3C4X20R': '2020 [Graduates + TxCHSE Recipients] for EL Rate',
#  'CE3C4X20N': '2020 [Graduates + TxCHSE Recipients] for Econ Disadv Numerator',
#  'CE3C4X20R': '2020 [Graduates + TxCHSE Recipients] for Econ Disadv Rate',
#  'CF3C4X20N': '2020 [Graduates + TxCHSE Recipients] for Female Numerator',
#  'CF3C4X20R': '2020 [Graduates + TxCHSE Recipients] for Female Rate',
#  'CH3C4X20N': '2020 [Graduates + TxCHSE Recipients] for Hispanic Numerator',
#  'CH3C4X20R': '2020 [Graduates + TxCHSE Recipients] for Hispanic Rate',
#  'CM3C4X20N': '2020 [Graduates + TxCHSE Recipients] for Male Numerator',
#  'CM3C4X20R': '2020 [Graduates + TxCHSE Recipients] for Male Rate',
#  'C43C4X20N': '2020 [Graduates + TxCHSE Recipients] for Pacific Islander Numerator',
#  'C43C4X20R': '2020 [Graduates + TxCHSE Recipients] for Pacific Islander Rate',
#  'CS3C4X20N': '2020 [Graduates + TxCHSE Recipients] for Special Ed Numerator',
#  'CS3C4X20R': '2020 [Graduates + TxCHSE Recipients] for Special Ed Rate',
#  'C23C4X20N': '2020 [Graduates + TxCHSE Recipients] for Two or More Races Numerator',
#  'C23C4X20R': '2020 [Graduates + TxCHSE Recipients] for Two or More Races Rate',
#  'CW3C4X20N': '2020 [Graduates + TxCHSE Recipients] for White Numerator',
#  'CW3C4X20R': '2020 [Graduates + TxCHSE Recipients] for White Rate',
#  'CBGC4X20N': '2020 [Graduates] for African American Numerator',
#  'CBGC4X20R': '2020 [Graduates] for African American Rate',
#  'CAGC4X20N': '2020 [Graduates] for All Students Numerator',
#  'CAGC4X20R': '2020 [Graduates] for All Students Rate',
#  'CIGC4X20N': '2020 [Graduates] for American Indian Numerator',
#  'CIGC4X20R': '2020 [Graduates] for American Indian Rate',
#  'C3GC4X20N': '2020 [Graduates] for Asian Numerator',
#  'C3GC4X20R': '2020 [Graduates] for Asian Rate',
#  'CRGC4X20N': '2020 [Graduates] for At Risk Numerator',
#  'CRGC4X20R': '2020 [Graduates] for At Risk Rate',
#  'CLGC4X20N': '2020 [Graduates] for EL Numerator',
#  'CLGC4X20R': '2020 [Graduates] for EL Rate',
#  'CEGC4X20N': '2020 [Graduates] for Econ Disadv Numerator',
#  'CEGC4X20R': '2020 [Graduates] for Econ Disadv Rate',
#  'CFGC4X20N': '2020 [Graduates] for Female Numerator',
#  'CFGC4X20R': '2020 [Graduates] for Female Rate',
#  'CHGC4X20N': '2020 [Graduates] for Hispanic Numerator',
#  'CHGC4X20R': '2020 [Graduates] for Hispanic Rate',
#  'CMGC4X20N': '2020 [Graduates] for Male Numerator',
#  'CMGC4X20R': '2020 [Graduates] for Male Rate',
#  'C4GC4X20N': '2020 [Graduates] for Pacific Islander Numerator',
#  'C4GC4X20R': '2020 [Graduates] for Pacific Islander Rate',
#  'CSGC4X20N': '2020 [Graduates] for Special Ed Numerator',
#  'CSGC4X20R': '2020 [Graduates] for Special Ed Rate',
#  'C2GC4X20N': '2020 [Graduates] for Two or More Races Numerator',
#  'C2GC4X20R': '2020 [Graduates] for Two or More Races Rate',
#  'CWGC4X20N': '2020 [Graduates] for White Numerator',
#  'CWGC4X20R': '2020 [Graduates] for White Rate',
#  'CBEC4X20N': '2020 [TxCHSE Recipients] for African American Numerator',
#  'CBEC4X20R': '2020 [TxCHSE Recipients] for African American Rate',
#  'CAEC4X20N': '2020 [TxCHSE Recipients] for All Students Numerator',
#  'CAEC4X20R': '2020 [TxCHSE Recipients] for All Students Rate',
#  'CIEC4X20N': '2020 [TxCHSE Recipients] for American Indian Numerator',
#  'CIEC4X20R': '2020 [TxCHSE Recipients] for American Indian Rate',
#  'C3EC4X20N': '2020 [TxCHSE Recipients] for Asian Numerator',
#  'C3EC4X20R': '2020 [TxCHSE Recipients] for Asian Rate',
#  'CREC4X20N': '2020 [TxCHSE Recipients] for At Risk Numerator',
#  'CREC4X20R': '2020 [TxCHSE Recipients] for At Risk Rate',
#  'CLEC4X20N': '2020 [TxCHSE Recipients] for EL Numerator',
#  'CLEC4X20R': '2020 [TxCHSE Recipients] for EL Rate',
#  'CEEC4X20N': '2020 [TxCHSE Recipients] for Econ Disadv Numerator',
#  'CEEC4X20R': '2020 [TxCHSE Recipients] for Econ Disadv Rate',
#  'CFEC4X20N': '2020 [TxCHSE Recipients] for Female Numerator',
#  'CFEC4X20R': '2020 [TxCHSE Recipients] for Female Rate',
#  'CHEC4X20N': '2020 [TxCHSE Recipients] for Hispanic Numerator',
#  'CHEC4X20R': '2020 [TxCHSE Recipients] for Hispanic Rate',
#  'CMEC4X20N': '2020 [TxCHSE Recipients] for Male Numerator',
#  'CMEC4X20R': '2020 [TxCHSE Recipients] for Male Rate',
#  'C4EC4X20N': '2020 [TxCHSE Recipients] for Pacific Islander Numerator',
#  'C4EC4X20R': '2020 [TxCHSE Recipients] for Pacific Islander Rate',
#  'CSEC4X20N': '2020 [TxCHSE Recipients] for Special Ed Numerator',
#  'CSEC4X20R': '2020 [TxCHSE Recipients] for Special Ed Rate',
#  'C2EC4X20N': '2020 [TxCHSE Recipients] for Two or More Races Numerator',
#  'C2EC4X20R': '2020 [TxCHSE Recipients] for Two or More Races Rate',
#  'CWEC4X20N': '2020 [TxCHSE Recipients] for White Numerator',
#  'CWEC4X20R': '2020 [TxCHSE Recipients] for White Rate',
#  'CB0C419D': '2019 African American Denominator (Federal Graduation without Exclusions)',
#  'CA0C419D': '2019 All Students Denominator (Federal Graduation without Exclusions)',
#  'CI0C419D': '2019 American Indian Denominator (Federal Graduation without Exclusions)',
#  'C30C419D': '2019 Asian Denominator (Federal Graduation without Exclusions)',
#  'CR0C419D': '2019 At Risk Denominator (Federal Graduation without Exclusions)',
#  'CL0C419D': '2019 EL Denominator (Federal Graduation without Exclusions)',
#  'CE0C419D': '2019 Econ Disadv Denominator (Federal Graduation without Exclusions)',
#  'CF0C419D': '2019 Female Denominator (Federal Graduation without Exclusions)',
#  'CH0C419D': '2019 Hispanic Denominator (Federal Graduation without Exclusions)',
#  'CM0C419D': '2019 Male Denominator (Federal Graduation without Exclusions)',
#  'C40C419D': '2019 Pacific Islander Denominator (Federal Graduation without Exclusions)',
#  'CS0C419D': '2019 Special Ed Denominator (Federal Graduation without Exclusions)',
#  'C20C419D': '2019 Two or More Races Denominator (Federal Graduation without Exclusions)',
#  'CW0C419D': '2019 White Denominator (Federal Graduation without Exclusions)',
#  'CBGC419N': '2019 [Graduates] for African American Numerator (Federal Graduation without Exclusions)',
#  'CBGC419R': '2019 [Graduates] for African American Rate (Federal Graduation without Exclusions)',
#  'CAGC419N': '2019 [Graduates] for All Students Numerator (Federal Graduation without Exclusions)',
#  'CAGC419R': '2019 [Graduates] for All Students Rate (Federal Graduation without Exclusions)',
#  'CIGC419N': '2019 [Graduates] for American Indian Numerator (Federal Graduation without Exclusions)',
#  'CIGC419R': '2019 [Graduates] for American Indian Rate (Federal Graduation without Exclusions)',
#  'C3GC419N': '2019 [Graduates] for Asian Numerator (Federal Graduation without Exclusions)',
#  'C3GC419R': '2019 [Graduates] for Asian Rate (Federal Graduation without Exclusions)',
#  'CRGC419N': '2019 [Graduates] for At Risk Numerator (Federal Graduation without Exclusions)',
#  'CRGC419R': '2019 [Graduates] for At Risk Rate (Federal Graduation without Exclusions)',
#  'CLGC419N': '2019 [Graduates] for EL Numerator (Federal Graduation without Exclusions)',
#  'CLGC419R': '2019 [Graduates] for EL Rate (Federal Graduation without Exclusions)',
#  'CEGC419N': '2019 [Graduates] for Econ Disadv Numerator (Federal Graduation without Exclusions)',
#  'CEGC419R': '2019 [Graduates] for Econ Disadv Rate (Federal Graduation without Exclusions)',
#  'CFGC419N': '2019 [Graduates] for Female Numerator (Federal Graduation without Exclusions)',
#  'CFGC419R': '2019 [Graduates] for Female Rate (Federal Graduation without Exclusions)',
#  'CHGC419N': '2019 [Graduates] for Hispanic Numerator (Federal Graduation without Exclusions)',
#  'CHGC419R': '2019 [Graduates] for Hispanic Rate (Federal Graduation without Exclusions)',
#  'CMGC419N': '2019 [Graduates] for Male Numerator (Federal Graduation without Exclusions)',
#  'CMGC419R': '2019 [Graduates] for Male Rate (Federal Graduation without Exclusions)',
#  'C4GC419N': '2019 [Graduates] for Pacific Islander Numerator (Federal Graduation without Exclusions)',
#  'C4GC419R': '2019 [Graduates] for Pacific Islander Rate (Federal Graduation without Exclusions)',
#  'CSGC419N': '2019 [Graduates] for Special Ed Numerator (Federal Graduation without Exclusions)',
#  'CSGC419R': '2019 [Graduates] for Special Ed Rate (Federal Graduation without Exclusions)',
#  'C2GC419N': '2019 [Graduates] for Two or More Races Numerator (Federal Graduation without Exclusions)',
#  'C2GC419R': '2019 [Graduates] for Two or More Races Rate (Federal Graduation without Exclusions)',
#  'CWGC419N': '2019 [Graduates] for White Numerator (Federal Graduation without Exclusions)',
#  'CWGC419R': '2019 [Graduates] for White Rate (Federal Graduation without Exclusions)',
#  'CB0C420D': '2020 African American Denominator (Federal Graduation without Exclusions)',
#  'CA0C420D': '2020 All Students Denominator (Federal Graduation without Exclusions)',
#  'CI0C420D': '2020 American Indian Denominator (Federal Graduation without Exclusions)',
#  'C30C420D': '2020 Asian Denominator (Federal Graduation without Exclusions)',
#  'CR0C420D': '2020 At Risk Denominator (Federal Graduation without Exclusions)',
#  'CL0C420D': '2020 EL Denominator (Federal Graduation without Exclusions)',
#  'CE0C420D': '2020 Econ Disadv Denominator (Federal Graduation without Exclusions)',
#  'CF0C420D': '2020 Female Denominator (Federal Graduation without Exclusions)',
#  'CH0C420D': '2020 Hispanic Denominator (Federal Graduation without Exclusions)',
#  'CM0C420D': '2020 Male Denominator (Federal Graduation without Exclusions)',
#  'C40C420D': '2020 Pacific Islander Denominator (Federal Graduation without Exclusions)',
#  'CS0C420D': '2020 Special Ed Denominator (Federal Graduation without Exclusions)',
#  'C20C420D': '2020 Two or More Races Denominator (Federal Graduation without Exclusions)',
#  'CW0C420D': '2020 White Denominator (Federal Graduation without Exclusions)',
#  'CBGC420N': '2020 [Graduates] for African American Numerator (Federal Graduation without Exclusions)',
#  'CBGC420R': '2020 [Graduates] for African American Rate (Federal Graduation without Exclusions)',
#  'CAGC420N': '2020 [Graduates] for All Students Numerator (Federal Graduation without Exclusions)',
#  'CAGC420R': '2020 [Graduates] for All Students Rate (Federal Graduation without Exclusions)',
#  'CIGC420N': '2020 [Graduates] for American Indian Numerator (Federal Graduation without Exclusions)',
#  'CIGC420R': '2020 [Graduates] for American Indian Rate (Federal Graduation without Exclusions)',
#  'C3GC420N': '2020 [Graduates] for Asian Numerator (Federal Graduation without Exclusions)',
#  'C3GC420R': '2020 [Graduates] for Asian Rate (Federal Graduation without Exclusions)',
#  'CRGC420N': '2020 [Graduates] for At Risk Numerator (Federal Graduation without Exclusions)',
#  'CRGC420R': '2020 [Graduates] for At Risk Rate (Federal Graduation without Exclusions)',
#  'CLGC420N': '2020 [Graduates] for EL Numerator (Federal Graduation without Exclusions)',
#  'CLGC420R': '2020 [Graduates] for EL Rate (Federal Graduation without Exclusions)',
#  'CEGC420N': '2020 [Graduates] for Econ Disadv Numerator (Federal Graduation without Exclusions)',
#  'CEGC420R': '2020 [Graduates] for Econ Disadv Rate (Federal Graduation without Exclusions)',
#  'CFGC420N': '2020 [Graduates] for Female Numerator (Federal Graduation without Exclusions)',
#  'CFGC420R': '2020 [Graduates] for Female Rate (Federal Graduation without Exclusions)',
#  'CHGC420N': '2020 [Graduates] for Hispanic Numerator (Federal Graduation without Exclusions)',
#  'CHGC420R': '2020 [Graduates] for Hispanic Rate (Federal Graduation without Exclusions)',
#  'CMGC420N': '2020 [Graduates] for Male Numerator (Federal Graduation without Exclusions)',
#  'CMGC420R': '2020 [Graduates] for Male Rate (Federal Graduation without Exclusions)',
#  'C4GC420N': '2020 [Graduates] for Pacific Islander Numerator (Federal Graduation without Exclusions)',
#  'C4GC420R': '2020 [Graduates] for Pacific Islander Rate (Federal Graduation without Exclusions)',
#  'CSGC420N': '2020 [Graduates] for Special Ed Numerator (Federal Graduation without Exclusions)',
#  'CSGC420R': '2020 [Graduates] for Special Ed Rate (Federal Graduation without Exclusions)',
#  'C2GC420N': '2020 [Graduates] for Two or More Races Numerator (Federal Graduation without Exclusions)',
#  'C2GC420R': '2020 [Graduates] for Two or More Races Rate (Federal Graduation without Exclusions)',
#  'CWGC420N': '2020 [Graduates] for White Numerator (Federal Graduation without Exclusions)',
#  'CWGC420R': '2020 [Graduates] for White Rate (Federal Graduation without Exclusions)',
#  'CAMPNAME': 'Campus Name',
#  'DISTNAME': 'District Name',
#  'DISTRICT': 'District Number'}

# %%
normalized_df = df[df.columns.intersection(final_table_columns)]
normalized_df = normalized_df.rename(columns=cols_map)

# %%
normalized_df['Campus Number'] = normalized_df['Campus Number'].str.strip("'")
normalized_df['District Number'] = normalized_df['District Number'].str.strip("'")

# %%
normalized_df
# Out:
#      Campus Number District Number  \
# 0        001902001          001902
# 1        001902041          001902
# 2        001902103          001902
# 3        001903001          001903
# 4        001903041          001903
# ...            ...             ...
# 8835     254901101          254901
# 8836     254901104          254901
# 8837     254901106          254901
# 8838     254902001          254902
# 8839     254902101          254902
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for All Students Numerator  \
# 0                                                  39.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  89.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                               41.0
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for African American Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   6.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for American Indian Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for Asian Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for Hispanic Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  10.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                               41.0
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for Pacific Islander Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for White Numerator  \
# 0                                                  33.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  67.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2020 [Graduates + TxCHSE Recipients + Continuers] for Two or More Races Numerator  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 8835  ...
# 8836  ...
# 8837  ...
# 8838  ...
# 8839  ...
#
#       2019 [Graduates] for White Rate (Federal Graduation without Exclusions)  \
# 0                                                  97.7
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  92.1
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2019 [Graduates] for Two or More Races Rate (Federal Graduation without Exclusions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2019 [Graduates] for Special Ed Rate (Federal Graduation without Exclusions)  \
# 0                                                  88.9
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  72.7
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#       2019 [Graduates] for At Risk Rate (Federal Graduation without Exclusions)  \
# 0                                                 100.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  78.3
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                               87.5
# 8839                                                NaN
#
#       2019 [Graduates] for Econ Disadv Rate (Federal Graduation without Exclusions)  \
# 0                                                  90.5
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  93.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                               93.1
# 8839                                                NaN
#
#       2019 [Graduates] for Female Rate (Federal Graduation without Exclusions)  \
# 0                                                 100.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                 100.0
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                               89.5
# 8839                                                NaN
#
#       2019 [Graduates] for Male Rate (Federal Graduation without Exclusions)  \
# 0                                                  93.5
# 1                                                   NaN
# 2                                                   NaN
# 3                                                  87.5
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                              100.0
# 8839                                                NaN
#
#       2019 [Graduates] for EL Rate (Federal Graduation without Exclusions)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8835                                                NaN
# 8836                                                NaN
# 8837                                                NaN
# 8838                                                NaN
# 8839                                                NaN
#
#                Campus Name     District Name
# 0               CAYUGA H S        CAYUGA ISD
# 1            CAYUGA MIDDLE        CAYUGA ISD
# 2                CAYUGA EL        CAYUGA ISD
# 3              ELKHART H S       ELKHART ISD
# 4           ELKHART MIDDLE       ELKHART ISD
# ...                    ...               ...
# 8835    DR TOMAS RIVERA EL  CRYSTAL CITY ISD
# 8836  BENITO JUAREZ MIDDLE  CRYSTAL CITY ISD
# 8837             ZAVALA EL  CRYSTAL CITY ISD
# 8838          LA PRYOR H S      LA PRYOR ISD
# 8839           LA PRYOR EL      LA PRYOR ISD
#
# [8840 rows x 452 columns]

# %%
normalized_df = normalized_df.set_index('Campus Number')
normalized_df.to_csv(f'{filename}_CLEAN.csv')
